# %%
import pandas as pd

train = pd.read_csv('train_data.csv')
val = pd.read_csv('validation_data.csv')
test = pd.read_csv('test_data.csv')

# %%
x_train = train.drop('Churn_Yes', axis=1)
y_train = train['Churn_Yes']

x_val = val.drop('Churn_Yes', axis=1)
y_val = val['Churn_Yes']

x_test = test.drop('Churn_Yes', axis=1)
y_test = test['Churn_Yes']

# %% [markdown]
# Logisttic regression model

# %%
from sklearn.linear_model import LogisticRegression

model1 = LogisticRegression()

model1.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


val_pred = model1.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics:")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:
# Accuracy:  0.7961
# Precision: 0.6387
# Recall   : 0.5114
# F1 Score : 0.5680

# %%
test_pred = model1.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:
# Accuracy:  0.8055
# Precision: 0.6633
# Recall   : 0.5603
# F1 Score : 0.6074

# %% [markdown]
# Model-2 DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier(max_depth=6, random_state=42)
model2.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, random_state=42)

# %%
val_pred = model2.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: Decision Tree Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: Decision Tree Validation data
# Accuracy:  0.8069
# Precision: 0.6424
# Recall   : 0.5937
# F1 Score : 0.6171

# %%
test_pred = model2.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  Decision Tree for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  Decision Tree for test data
# Accuracy:  0.7910
# Precision: 0.6215
# Recall   : 0.5677
# F1 Score : 0.5934

# %% [markdown]
# Model-3 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model3 = RandomForestClassifier(n_estimators=200, random_state=42)
model3.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
val_pred = model2.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: Random Forest Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: Random Forest Validation data
# Accuracy:  0.8069
# Precision: 0.6424
# Recall   : 0.5937
# F1 Score : 0.6171

# %%
test_pred = model2.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  Random Forest for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  Random Forest for test data
# Accuracy:  0.7910
# Precision: 0.6215
# Recall   : 0.5677
# F1 Score : 0.5934

# %% [markdown]
# I will train Model 3- Random forest by adjusting parameters for more accuracy

# %%
model3_1 = RandomForestClassifier(n_estimators=2000, random_state=42)
model3_1.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=2000, random_state=42)

# %%
val_pred = model3_1.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: Random Forest with different parameters Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: Random Forest with different parameters Validation data
# Accuracy:  0.9972
# Precision: 0.9946
# Recall   : 0.9946
# F1 Score : 0.9946

# %%
test_pred = model3_1.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  Random Forest with different parameters for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  Random Forest with different parameters for test data
# Accuracy:  0.8339
# Precision: 0.7311
# Recall   : 0.6036
# F1 Score : 0.6613

# %% [markdown]
# Checking scores for decision tree by adjusting parameters

# %%
from sklearn.tree import DecisionTreeClassifier
model2_1 = DecisionTreeClassifier(max_depth=10, random_state=42)
model2_1.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
val_pred = model2_1.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: Descision Tree Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: Descision Tree Validation data
# Accuracy:  0.8739
# Precision: 0.8082
# Recall   : 0.6804
# F1 Score : 0.7388

# %%
test_pred = model2_1.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  Descision Tree for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  Descision Tree for test data
# Accuracy:  0.7783
# Precision: 0.5998
# Recall   : 0.5243
# F1 Score : 0.5595

# %% [markdown]
# Gradient Bosting Model

# %%
from sklearn.ensemble import GradientBoostingClassifier
model4 = GradientBoostingClassifier(random_state=42)
model4.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
val_pred = model4.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: Gradient Boosting Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: Gradient Boosting Validation data
# Accuracy:  0.8216
# Precision: 0.7046
# Recall   : 0.5504
# F1 Score : 0.6180

# %%
test_pred = model4.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  Gradient Boosting for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  Gradient Boosting for test data
# Accuracy:  0.8072
# Precision: 0.6736
# Recall   : 0.5476
# F1 Score : 0.6041

# %% [markdown]
# XGBoost model

# %%
from xgboost import XGBClassifier
model5 = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
model5.fit(x_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [14:38:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
val_pred = model5.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: XGBoost Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: XGBoost Validation data
# Accuracy:  0.9384
# Precision: 0.9030
# Recall   : 0.8570
# F1 Score : 0.8794

# %%
test_pred = model5.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  XGBoost for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  XGBoost for test data
# Accuracy:  0.8183
# Precision: 0.6787
# Recall   : 0.6142
# F1 Score : 0.6448

# %% [markdown]
# K-nearest Neighbors model

# %%
from sklearn.neighbors import KNeighborsClassifier
model6 = KNeighborsClassifier(n_neighbors=5)
model6.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
val_pred = model6.predict(x_val)

val_accuracy = accuracy_score(y_val, val_pred)
precision = precision_score(y_val, val_pred)
recall = recall_score(y_val, val_pred)
f1 = f1_score(y_val, val_pred)


print("Model Evaluation Metrics: KNN Validation data")
print(f"Accuracy:  {val_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics: KNN Validation data
# Accuracy:  0.8358
# Precision: 0.7117
# Recall   : 0.6284
# F1 Score : 0.6674

# %%
test_pred = model6.predict(x_test)

test_accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred)
recall = recall_score(y_test, test_pred)
f1 = f1_score(y_test, test_pred)


print("Model Evaluation Metrics:  KNN for test data")
print(f"Accuracy:  {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Model Evaluation Metrics:  KNN for test data
# Accuracy:  0.7885
# Precision: 0.6157
# Recall   : 0.5655
# F1 Score : 0.5895

# %%
model_score = pd.read_csv('model_score.csv')
model_score
# Out:
#   Model Number                         Model  ... F1 score val F1 score tset
# 0       model1            LogisticRegression  ...          56%           60%
# 1       model2                 Decision Tree  ...          61%           59%
# 2      model3                  Random Forest  ...          61%           59%
# 3     model3_1         Random Forest(n=2000)  ...          99%           66%
# 4     model2_1  Decision Tree (max_depth=10)  ...          73%           55%
# 5       model4             Gradient Boosting  ...          61%           60%
# 6       model5                       XGBoost  ...          87%           64%
# 7       model6                           KNN  ...          66%           58%
#
# [8 rows x 10 columns]

# %% [markdown]
# Conclusion - XGBoost model has performed well, So i will proceed to train the model with different parameters to achive the best model.
